# %%
from pyspark.streaming import StreamingContext
import time
ssc = StreamingContext(sc , 5)
lines = ssc.textFileStream("file:///home/aravindan81222/streaming/")
words=lines.flatMap(lambda line:line.split(" "))
pairs=words.map(lambda word:(word,1))
wordCounts=pairs.reduceByKey(lambda x,y : x+y)
wordCounts.pprint()
ssc.start()
time.sleep(60)
ssc.stop(stopSparkContext=False)
# Out:
# -------------------------------------------
# Time: 2019-05-02 22:30:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-02 22:31:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-02 22:31:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-02 22:31:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-02 22:31:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-02 22:31:20
# -------------------------------------------
# ('"2019-03-01","00:57:37",12653,"3.5.2","x86_64","mingw32","gifski","0.8.6","US",16', 1)
# ('"2019-03-01","00:57:30",359783,"3.5.2","x86_64","mingw32","lmtest","0.9-36","US",52', 1)
# ('"2019-03-01","00:57:15",574355,"3.3.3","x86_64","darwin13.4.0","alr4","1.0.6","US",9', 1)
# ('"2019-03-01","00:57:57",1555484,"3.5.1","x86_64","mingw32","vcd","1.4-4","US",40', 1)
# ('"2019-03-01","00:57:47",49429,NA,NA,NA,"ISwR","2.0-7","US",107', 1)
# ('"2019-03-01","00:52:06",41788,"3.5.2","x86_64","mingw32","callr","3.1.1","US",75', 1)
# ('"2019-03-01","00:53:03",14246,"3.5.1","x86_64","linux-gnu","clipr","0.5.0","US",28', 1)
# ('"2019-03-01","00:57:30",3534672,"3.4.1","x86_64","mingw32","xml2","1.2.0","US",42', 1)
# ('"2019-03-01","00:57:19",540984,"3.5.2","x86_64","mingw32","dbplyr","1.3.0","US",26', 1)
# ('"2019-03-01","00:57:21",218844,"3.4.2","x86_64","mingw32","checkmate","1.9.1","US",32', 1)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:31:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-02 22:31:30
# -------------------------------------------
# ('"2019-03-01","00:58:32",70968,"3.5.2","x86_64","mingw32","logspline","2.1.12","US",16', 1)
# ('"2019-03-01","00:58:18",757617,"3.5.2","x86_64","mingw32","libcoin","1.0-4","JP",159', 1)
# ('"2019-03-01","00:47:07",194474,"3.5.1","x86_64","mingw32","utf8","1.1.4","US",104', 1)
# ('"2019-03-01","00:58:52",3177912,"3.4.4","x86_64","linux-gnu","ggplot2","3.1.0","MX",216', 1)
# ('"2019-03-01","00:58:34",108385,"3.5.2","x86_64","darwin18.2.0","ROCR","1.0-7","US",184', 1)
# ('"2019-03-01","00:58:34",346191,"3.5.2","x86_64","darwin15.6.0","swirl","2.4.3","CL",185', 1)
# ('"2019-03-01","00:58:51",124099,"3.4.4","x86_64","linux-gnu","withr","2.1.2","MX",192', 1)
# ('"2019-03-01","00:58:38",58848,"3.5.1","x86_64","linux-gnu","R6","2.4.0","AU",196', 1)
# ('"2019-03-01","00:58:33",739741,"3.3.2","x86_64","linux-gnu","tibble","2.0.1","US",173', 1)
# ('"2019-03-01","00:47:21",19600,"3.5.2","x86_64","mingw32","xopen","1.0.0","US",141', 1)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:31:35
# -------------------------------------------
# ('"2019-03-01","00:59:36",307831,"3.5.2","x86_64","mingw32","processx","3.2.1","MX",275', 1)
# ('"2019-03-01","00:59:02",44523,"3.5.1","x86_64","linux-gnu","viridisLite","0.3.0","US",119', 1)
# ('"2019-03-01","00:59:02",188286,"3.4.4","x86_64","linux-gnu","mindr","1.2.1","PR",229', 1)
# ('"2019-03-01","00:59:05",23488,"3.3.3","x86_64","darwin13.4.0","evaluate","0.13","CA",8', 1)
# ('"2019-03-01","00:59:42",4310433,"3.5.1","x86_64","mingw32","mclust","5.4.2","CO",169', 1)
# ('"2019-03-01","00:59:31",450366,"3.5.2","i386","mingw32","lubridate","1.7.4","US",150', 1)
# ('"2019-03-01","00:59:33",20813,"3.5.1","x86_64","mingw32","zeligverse","0.1.1","US",16', 1)
# ('"2019-03-01","00:59:16",274169,"3.4.4","x86_64","linux-gnu","gtools","3.8.1","US",258', 1)
# ('"2019-03-01","00:59:06",1483976,"3.5.2","x86_64","linux-gnu","reticulate","1.11","PR",229', 1)
# ('"2019-03-01","00:59:00",734253,"3.5.2","x86_64","mingw32","tibble","2.0.1","US",217', 1)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:31:40
# -------------------------------------------
# ('"2019-03-01","00:59:45",3240779,"3.3.3","x86_64","linux-gnu","dplyr","0.8.0.1","US",279', 1)
# ('"2019-03-01","00:50:24",6244,"3.5.1","x86_64","mingw32","askpass","1.1","US",66', 1)
# ('"2019-03-01","00:59:48",2872750,"3.3.3","x86_64","darwin13.4.0","git2r","0.24.0","US",304', 1)
# ('"2019-03-01","08:52:22",57696,"3.2.4","x86_64","darwin13.4.0","VetResearchLMM","1.0.0","JP",374', 1)
# ('"2019-03-01","08:52:31",24796,"3.4.4","x86_64","linux-gnu","aws.signature","0.4.4","US",363', 1)
# ('"2019-03-01","00:59:46",38998,"3.3.3","x86_64","linux-gnu","nortest","1.0-4","CO",25', 1)
# ('"2019-03-01","00:59:42",517,"3.3.3","x86_64","linux-gnu","ggplot2","3.1.0","US",296', 1)
# ('"2019-03-01","00:59:35",83132,"3.5.1","x86_64","mingw32","progress","1.2.0","CA",284', 1)
# ('"2019-03-01","08:52:28",2996058,"3.5.2","x86_64","mingw32","curl","3.3","IN",380', 1)
# ('"2019-03-01","08:52:16",11233,"3.5.2","x86_64","mingw32","labeling","0.3","US",340', 1)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:31:45
# -------------------------------------------
# ('"2019-03-01","08:52:49",123801,"3.5.2","x86_64","mingw32","vmd","0.1.0","JP",374', 1)
# ('"2019-03-01","08:52:52",109127,"3.5.2","x86_64","linux-gnu","glue","1.3.0","IN",384', 1)
# ('"2019-03-01","08:52:37",2545513,"3.5.2","x86_64","mingw32","colorspace","1.4-0","FR",407', 1)
# ('"2019-03-01","08:52:39",80605,"3.5.2","x86_64","mingw32","lazyeval","0.2.1","CA",8', 1)
# ('"2019-03-01","08:52:39",521250,"3.5.2","x86_64","mingw32","prettydoc","0.2.1","RU",354', 1)
# ('"2019-03-01","08:52:36",13637719,NA,NA,NA,"mapdata","2.3.0","US",358', 1)
# ('"2019-03-01","08:52:55",488373,"3.4.3","x86_64","mingw32","nloptr","1.2.1","JP",341', 1)
# ('"2019-03-01","08:52:31",749921,"3.5.2","x86_64","mingw32","crayon","1.3.4","IN",384', 1)
# ('"2019-03-01","08:52:36",2246977,"3.5.1","x86_64","mingw32","RcppArmadillo","0.9.200.7.0","CN",408', 1)
# ('"2019-03-01","08:52:40",2702810,"3.5.2","x86_64","linux-gnu","openxlsx","4.1.0","GB",424', 1)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:31:50
# -------------------------------------------
# ('"2019-03-01","08:53:16",86198,"3.5.1","x86_64","mingw32","gtable","0.2.0","NL",515', 1)
# ('"2019-03-01","08:53:26",685494,"3.5.2","x86_64","mingw32","hexbin","1.27.2","CH",472', 1)
# ('"2019-03-01","08:53:26",665910,"3.5.2","x86_64","linux-gnu","crosstalk","1.0.0","RU",548', 1)
# ('"2019-03-01","08:53:15",53455,"3.5.2","x86_64","mingw32","RColorBrewer","1.1-2","NL",515', 1)
# ('"2019-03-01","08:53:24",74527,"3.5.1","x86_64","mingw32","evaluate","0.13","DK",414', 1)
# ('"2019-03-01","08:53:34",153030,"3.5.1","x86_64","darwin15.6.0","fpc","2.1-11.1","RU",549', 1)
# ('"2019-03-01","08:53:24",195086,"3.4.4","x86_64","linux-gnu","digest","0.6.18",NA,18', 1)
# ('"2019-03-01","08:53:17",2044215,"3.5.2","x86_64","mingw32","rms","5.1-3","BE",471', 1)
# ('"2019-03-01","08:53:05",15271903,"3.5.2","x86_64","mingw32","stringi","1.3.1","JP",364', 1)
# ('"2019-03-01","08:53:21",60935,"3.4.4","x86_64","linux-gnu","viridisLite","0.3.0","CN",417', 1)
# ...

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import Row
import time
ssc=StreamingContext(sc, 5)
def save(time,rdd):
    try:
        df = spark.createDataFrame(rdd.map(\
        lambda row: Row(package=row[0], count=row[1],time=time)))
        df.write.format("org.apache.spark.sql.cassandra")\
        .options(table="questionfour", keyspace="streaming")\
        .save(mode="append")
    except:
        pass
lines = ssc.textFileStream("file:///home/aravindan81222/streaming/")
downloads_RDD = lines.map(lambda x: x.split(','))
def remove_quotation(x):
        return([xx.replace('"','')for xx in x])
downloads_RDD = downloads_RDD.map(remove_quotation)
five = downloads_RDD.map(lambda x: (x[6], 1))
five = five.reduceByKey(lambda a,b: a + b)
five = five.filter(lambda x: "ggplot2" in x)
#five.foreachRDD(save)
five.pprint()
ssc.start()
time.sleep(60)
ssc.stop(stopSparkContext=False)
# Out:
# -------------------------------------------
# Time: 2019-05-02 22:31:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-02 22:32:00
# -------------------------------------------
# ('ggplot2', 10)
#
# -------------------------------------------
# Time: 2019-05-02 22:32:05
# -------------------------------------------
# ('ggplot2', 18)
#
# -------------------------------------------
# Time: 2019-05-02 22:32:10
# -------------------------------------------
# ('ggplot2', 14)
#
# -------------------------------------------
# Time: 2019-05-02 22:32:15
# -------------------------------------------
# ('ggplot2', 13)
#
# -------------------------------------------
# Time: 2019-05-02 22:32:20
# -------------------------------------------
# ('ggplot2', 12)
#
# -------------------------------------------
# Time: 2019-05-02 22:32:25
# -------------------------------------------
# ('ggplot2', 14)
#
# -------------------------------------------
# Time: 2019-05-02 22:32:30
# -------------------------------------------
# ('ggplot2', 16)
#
# -------------------------------------------
# Time: 2019-05-02 22:32:35
# -------------------------------------------
# ('ggplot2', 9)
#
# -------------------------------------------
# Time: 2019-05-02 22:32:40
# -------------------------------------------
# ('ggplot2', 11)
#
# -------------------------------------------
# Time: 2019-05-02 22:32:45
# -------------------------------------------
# ('ggplot2', 14)
#
# -------------------------------------------
# Time: 2019-05-02 22:32:50
# -------------------------------------------
# ('ggplot2', 5)

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import Row
import time
ssc  = StreamingContext(sc, 5)
def save(time,rdd):
    try:
        df = spark.createDataFrame(rdd.map(\
        lambda row: Row(package=row[0], count=row[1],time=time)))
        df.write.format("org.apache.spark.sql.cassandra")\
        .options(table="questionone", keyspace="database")\
        .save(mode="append")
    except:
        pass
lines = ssc.textFileStream("file:///home/aravindan81222/streaming/")
downloads_RDD = lines.map(lambda x: x.split(','))
def remove_quotation(x):
        return([xx.replace('"','')for xx in x])   
downloads_RDD = downloads_RDD.map(remove_quotation)
words = downloads_RDD.map(lambda x: (x[6], 1))
words = words.reduceByKey(lambda a , b: a + b)
#values.foreachRDD(save)
words.pprint()
ssc.start()
time.sleep(60)
ssc.stop(stopSparkContext=False)
# Out:
# -------------------------------------------
# Time: 2019-05-02 22:32:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-02 22:33:00
# -------------------------------------------
# ('bestNormalize', 1)
# ('manipulate', 1)
# ('lubridate', 1)
# ('ModelMetrics', 1)
# ('crayon', 10)
# ('loo', 1)
# ('Rdpack', 1)
# ('qicharts', 1)
# ('ggplot2', 9)
# ('RcppArmadillo', 2)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:33:05
# -------------------------------------------
# ('lubridate', 6)
# ('english', 1)
# ('crayon', 7)
# ('callr', 7)
# ('ggplot2', 12)
# ('kimisc', 1)
# ('prodlim', 1)
# ('units', 2)
# ('tidyverse', 6)
# ('cli', 9)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:33:10
# -------------------------------------------
# ('crayon', 17)
# ('tree', 2)
# ('ggplot2', 5)
# ('RcppArmadillo', 9)
# ('arulesViz', 1)
# ('prodlim', 1)
# ('units', 2)
# ('tidyverse', 5)
# ('cli', 9)
# ('reshape2', 1)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:33:15
# -------------------------------------------
# ('ModelMetrics', 1)
# ('crayon', 13)
# ('loo', 2)
# ('ggplot2', 8)
# ('stargazer', 1)
# ('prodlim', 1)
# ('units', 1)
# ('tidyverse', 3)
# ('cli', 17)
# ('PearsonDS', 1)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:33:20
# -------------------------------------------
# ('crayon', 9)
# ('seacarb', 1)
# ('ggplot2', 7)
# ('RcppArmadillo', 3)
# ('soiltexture', 1)
# ('tidyverse', 4)
# ('cli', 13)
# ('reshape2', 7)
# ('dplyr', 16)
# ('tensorflow', 1)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:33:25
# -------------------------------------------
# ('hunspell', 1)
# ('lubridate', 4)
# ('crayon', 10)
# ('ggplot2', 10)
# ('RcppArmadillo', 4)
# ('prodlim', 1)
# ('tidyverse', 5)
# ('cli', 6)
# ('reshape2', 6)
# ('memoise', 4)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:33:30
# -------------------------------------------
# ('compare', 1)
# ('crayon', 4)
# ('ggplot2', 10)
# ('RcppArmadillo', 1)
# ('multcompView', 1)
# ('questionr', 3)
# ('units', 4)
# ('tidyverse', 6)
# ('cli', 6)
# ('digest', 3)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:33:35
# -------------------------------------------
# ('crayon', 8)
# ('rvcheck', 1)
# ('ggplot2', 9)
# ('RcppArmadillo', 1)
# ('questionr', 2)
# ('naivebayes', 1)
# ('PK', 1)
# ('cli', 10)
# ('digest', 3)
# ('multicool', 1)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:33:40
# -------------------------------------------
# ('Ckmeans.1d.dp', 1)
# ('crayon', 10)
# ('ggplot2', 6)
# ('arulesViz', 1)
# ('tidyverse', 2)
# ('cli', 12)
# ('yaImpute', 2)
# ('reshape2', 4)
# ('Cairo', 1)
# ('PCICt', 1)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:33:45
# -------------------------------------------
# ('multcompView', 1)
# ('plotROC', 1)
# ('crayon', 4)
# ('callr', 5)
# ('ggplot2', 9)
# ('RcppArmadillo', 4)
# ('stargazer', 1)
# ('questionr', 1)
# ('units', 2)
# ('tidyverse', 2)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:33:50
# -------------------------------------------
# ('compare', 1)
# ('crayon', 10)
# ('mlflow', 1)
# ('ggplot2', 8)
# ('RcppArmadillo', 2)
# ('stargazer', 1)
# ('questionr', 1)
# ('units', 3)
# ('tidyverse', 2)
# ('cli', 12)
# ...

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import Row
import time
def save(time,rdd):
    try:
        df = spark.createDataFrame(rdd.map(\
        lambda row: Row(package=row[0], count=row[1],time=time)))
        df.write.format("org.apache.spark.sql.cassandra")\
        .options(table="questiontwo", keyspace="database")\
        .save(mode="append")
    except:
        pass
ssc  = StreamingContext(sc, 5)
lines = ssc.textFileStream("file:///home/aravindan81222/streaming/")
downloads_RDD=lines.map(lambda line:line.split(","))
def remove_quotation(x):
        return([xx.replace('"','')for xx in x]) 
downloads_RDD=downloads_RDD.map(remove_quotation)
words=downloads_RDD.map(lambda y:(y[6],1))
words = words.reduceByKey(lambda a , b: a + b)
words = words.transform((lambda variable:variable.sortBy(lambda x:(-x[1]))))
words.pprint(1)
ssc.start()
time.sleep(60)
ssc.stop(stopSparkContext=False)
# Out:
# -------------------------------------------
# Time: 2019-05-02 22:33:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-02 22:34:00
# -------------------------------------------
# ('tibble', 20)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:34:05
# -------------------------------------------
# ('htmltools', 27)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:34:10
# -------------------------------------------
# ('Rcpp', 13)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:34:15
# -------------------------------------------
# ('rlang', 35)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:34:20
# -------------------------------------------
# ('polynom', 32)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:34:25
# -------------------------------------------
# ('psych', 31)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:34:30
# -------------------------------------------
# ('webshot', 30)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:34:35
# -------------------------------------------
# ('rlang', 23)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:34:40
# -------------------------------------------
# ('rlang', 18)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:34:45
# -------------------------------------------
# ('tibble', 29)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:34:50
# -------------------------------------------
# ('pillar', 13)
# ...

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import Row
import time
def save(time,rdd):
    try:
        df = spark.createDataFrame(rdd.map(\
        lambda row: Row(country=row[0], count=row[1],time=time)))
        df.write.format("org.apache.spark.sql.cassandra")\
        .options(table="questionthree", keyspace="database")\
        .save(mode="append")
    except:
        pass
ssc  = StreamingContext(sc, 5)
lines = ssc.textFileStream("file:///home/aravindan81222/streaming/")
downloads_RDD=lines.map(lambda line:line.split(","))
def remove_quotation(x):
        return([xx.replace('"','')for xx in x]) 
downloads_RDD=downloads_RDD.map(remove_quotation)
words=downloads_RDD.map(lambda y:(y[8],1))
words = words.reduceByKey(lambda a , b: a + b)
words = words.transform((lambda variable:variable.sortBy(lambda x:(-x[1]))))
words.pprint(5)
ssc.start()
time.sleep(60)
ssc.stop(stopSparkContext=False)
# Out:
# -------------------------------------------
# Time: 2019-05-02 22:34:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-02 22:35:00
# -------------------------------------------
# ('US', 367)
# ('FR', 106)
# ('NO', 98)
# ('HK', 60)
# ('JP', 51)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:35:05
# -------------------------------------------
# ('US', 425)
# ('FR', 96)
# ('IN', 70)
# ('NL', 54)
# ('CA', 47)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:35:10
# -------------------------------------------
# ('US', 614)
# ('FR', 75)
# ('IN', 68)
# ('DE', 53)
# ('HK', 34)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:35:15
# -------------------------------------------
# ('US', 1067)
# ('DE', 152)
# ('JP', 127)
# ('HK', 83)
# ('FR', 74)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:35:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-02 22:35:25
# -------------------------------------------
# ('US', 439)
# ('JP', 75)
# ('NO', 62)
# ('DE', 59)
# ('FR', 47)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:35:30
# -------------------------------------------
# ('US', 233)
# ('FR', 165)
# ('NA', 76)
# ('CN', 73)
# ('ES', 62)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:35:35
# -------------------------------------------
# ('US', 239)
# ('IN', 118)
# ('CN', 95)
# ('HK', 83)
# ('DE', 80)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:35:40
# -------------------------------------------
# ('US', 290)
# ('DE', 84)
# ('NA', 81)
# ('JP', 69)
# ('CN', 64)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:35:45
# -------------------------------------------
# ('US', 316)
# ('NA', 143)
# ('AU', 106)
# ('CN', 91)
# ('DE', 63)
# ...
#
# -------------------------------------------
# Time: 2019-05-02 22:35:50
# -------------------------------------------
# ('US', 298)
# ('NA', 196)
# ('CN', 131)
# ('CA', 87)
# ('AU', 70)
# ...
